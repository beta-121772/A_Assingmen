# %% [markdown]
# <a href="https://colab.research.google.com/github/beta-121772/A_Assingmen/blob/2/PROBLEM_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
import zipfile
import tensorflow as tf
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator # saya pake google colab
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop



def solution_A2():
    data_url_1 = 'https://github.com/dicodingacademy/assets/releases/download/release-horse-or-human/horse-or-human.zip'
    urllib.request.urlretrieve(data_url_1, 'horse-or-human.zip')
    local_file = 'horse-or-human.zip'
    zip_ref = zipfile.ZipFile(local_file, 'r')
    zip_ref.extractall('data/horse-or-human')

    data_url_2 = 'https://github.com/dicodingacademy/assets/raw/main/Simulation/machine_learning/validation-horse-or-human.zip'
    urllib.request.urlretrieve(data_url_2, 'validation-horse-or-human.zip')
    local_file = 'validation-horse-or-human.zip'
    zip_ref = zipfile.ZipFile(local_file, 'r')
    zip_ref.extractall('data/validation-horse-or-human')
    zip_ref.close()

    TRAINING_DIR = 'data/horse-or-human'
    VAL_DIR = 'data/validation-horse-or-human'
    train_datagen = ImageDataGenerator(
        rescale=1/255,
        rotation_range=40,
        horizontal_flip=True,
        shear_range=0.2,
        zoom_range=0.2,
        width_shift_range=0.2,
        height_shift_range=0.2,
        fill_mode='nearest'
    )
        # YOUR CODE HERE)

    # YOUR IMAGE SIZE SHOULD BE 150x150
    train_generator= train_datagen.flow_from_directory(
        TRAINING_DIR,
        target_size=(150, 150),
        batch_size=128,
        class_mode='binary'
    ) # YOUR CODE HERE

    test_datagen = ImageDataGenerator(rescale=1./255)
    validation_generator = test_datagen.flow_from_directory(VAL_DIR,
                                                            class_mode='binary',
                                                            batch_size=32,
                                                            target_size=(150, 150))

    class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs={}):
            if(logs.get('accuracy') > 0.83 and logs.get('val_accuracy') > 0.83):
                print("\n acurasi udah 83% lebih")
                self.model.stop_training = True

    model=tf.keras.models.Sequential([
        # YOUR CODE HERE, end with a Neuron Dense, activated by sigmoid
                tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)),
                tf.keras.layers.MaxPooling2D(2, 2),
                tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
                tf.keras.layers.MaxPooling2D(2, 2),
                tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                tf.keras.layers.MaxPooling2D(2, 2),
                tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
                tf.keras.layers.MaxPooling2D(2, 2),
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(512, activation='relu'),
                tf.keras.layers.Dense(1, activation='sigmoid')
              ])

    model.compile(
        optimizer=RMSprop(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=["accuracy"]
    )
    model.fit(
        train_generator,
        epochs=1000,
        validation_data=validation_generator,
        callbacks=[myCallback()]
    )

    return model


# The code below is to save your model as a .h5 file.
# It will be saved automatically in your Submission folder.
if __name__ == '__main__':
    # DO NOT CHANGE THIS CODE
    model=solution_A2()
    model.save("model_A2.h5")
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Epoch 1/1000
# 9/9 [==============================] - 48s 5s/step - loss: 0.7976 - accuracy: 0.4722 - val_loss: 0.6863 - val_accuracy: 0.5039
# Epoch 2/1000
# 9/9 [==============================] - 38s 4s/step - loss: 0.8363 - accuracy: 0.5550 - val_loss: 0.6750 - val_accuracy: 0.5000
# Epoch 3/1000
# 9/9 [==============================] - 39s 5s/step - loss: 0.6803 - accuracy: 0.6436 - val_loss: 0.6495 - val_accuracy: 0.6445
# Epoch 4/1000
# 9/9 [==============================] - 40s 4s/step - loss: 0.6934 - accuracy: 0.5959 - val_loss: 0.7107 - val_accuracy: 0.5195
# Epoch 5/1000
# 9/9 [==============================] - 38s 4s/step - loss: 0.7141 - accuracy: 0.6339 - val_loss: 0.7096 - val_accuracy: 0.5000
# Epoch 6/1000
# 9/9 [==============================] - 40s 4s/step - loss: 0.6806 - accuracy: 0.5404 - val_loss: 0.6817 - val_accuracy: 0.5000
# Epoch 7/1000
# 9/9 [==============================] - 38s 4s/step - loss: 0.6764 - accuracy: 0.5842 - val_loss: 0.5391 - val_accuracy: 0.9336
# Epoch 8/1000
# 9/9 [==============================] - 38s 5s/step - loss: 0.7022 - accuracy: 0.6261 - val_loss: 0.7434 - val_accuracy: 0.5000
# Epoch 9/1000
# 9/9 [==============================] - 39s 4s/step - loss: 0.6205 - accuracy: 0.6699 - val_loss: 0.5502 - val_accuracy: 0.6289
# Epoch 10/1000
# 9/9 [==============================] - 40s 4s/step - loss: 0.6206 - accuracy: 0.7040 - val_loss: 0.4724 - val_accuracy: 0.7812
# Epoch 11/1000
# 9/9 [==============================] - 39s 4s/step - loss: 0.5792 - accuracy: 0.6865 - val_loss: 0.2409 - val_accuracy: 0.9102
# Epoch 12/1000
# 9/9 [==============================] - 39s 4s/step - loss: 0.5589 - accuracy: 0.7147 - val_loss: 0.7233 - val_accuracy: 0.6836
# Epoch 13/1000
# 9/9 [==============================] - 47s 5s/step - loss: 0.4878 - accuracy: 0.7575 - val_loss: 1.1654 - val_accuracy: 0.6211
# Epoch 14/1000
# 9/9 [==============================] - 41s 4s/step - loss: 0.5088 - accuracy: 0.7371 - val_loss: 0.4853 - val_accuracy: 0.7852
# Epoch 15/1000
# 9/9 [==============================] - 39s 4s/step - loss: 0.3963 - accuracy: 0.8111 - val_loss: 0.2161 - val_accuracy: 0.9102
# Epoch 16/1000
# 9/9 [==============================] - 38s 5s/step - loss: 0.4159 - accuracy: 0.8160 - val_loss: 0.2313 - val_accuracy: 0.9102
# Epoch 17/1000
# 9/9 [==============================] - 39s 4s/step - loss: 0.6327 - accuracy: 0.7712 - val_loss: 0.5401 - val_accuracy: 0.7773
# Epoch 18/1000
# 9/9 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8520
#  acurasi udah 83% lebih
# 9/9 [==============================] - 40s 4s/step - loss: 0.3198 - accuracy: 0.8520 - val_loss: 0.4362 - val_accuracy: 0.8477
